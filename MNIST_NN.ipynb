# %% [markdown]
# Require Lib

# %%
import torch
import torchvision
from torchvision.datasets import MNIST
import matplotlib.pyplot as plt
import os
import torchvision.transforms as transform
import pandas as pd
from torch.utils.data import random_split
from torch.utils.data import DataLoader
import torch.nn.functional as F

# %% [markdown]
# Download Dataset

# %%
dataset = MNIST(root = '/data' , download = True) #tải data về
print(len(dataset))
# Out:
# 60000

# %%
image , label = dataset[1] # do mỗi phần tử của dataset có 1 thành phần 1 là ma trận biểu diễn điểm ảnh 2 là nhãn của điểm ảnh
#cho biết ảnh là số mấy.
plt.imshow(image, cmap = 'gray')
print(label)
# Out:
# 0

# %%
data = MNIST(root = '/data' , train= True, transform = transform.ToTensor())
print(data)
image_tensor, label = data[1]
print(image_tensor.shape, label)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()
# torch.Size([1, 28, 28]) 0

# %%
print(image_tensor[:, 10:15,10:15])
print(torch.max(image_tensor) , torch.min(image_tensor))
plt.imshow(image_tensor[0,10:15,10:15],cmap = 'gray')
# Out:
# tensor([[[0.9333, 0.9882, 0.9882, 0.7020, 0.0471],
#          [0.9922, 0.9137, 0.8157, 0.3294, 0.0000],
#          [0.9412, 0.2784, 0.0745, 0.1098, 0.0000],
#          [0.2471, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000]]])
# tensor(1.) tensor(0.)

# %% [markdown]
# Training and Valiations Dataset
